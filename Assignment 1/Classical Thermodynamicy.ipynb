# %% [markdown]
# ## 1) Langmuir model, basic three assumptions
#
# 1. Monolayer adsorption only
#    Each adsorption site on the solid surface can hold at most one molecule.
#    In other words, once a site is occupied, no further molecules can adsorb at that site.
#
# 2. Identical and independent adsorption sites
#    All adsorption sites are energetically equivalent, i.e. same adsorption energy and do not interact with one another.
#    Occupation of one site does not change the adsorption energy of other sites.
#
# 3. Dynamic equilibrium between adsorption and desorption
#    Adsorption and desorption are reversible; at equilibrium the rate of adsorption equals the rate of desorption.
#    This balance leads to the Langmuir isotherm.

# %% [markdown]
# ## 2) Limiting behaviour of the Langmuir isotherm
#
# The Langmuir isotherm is given by
#
# $$
# q(P,T) = \frac{q_{\text{sat}} \, k(T) \, P}{1 + k(T) \, P}
# $$
#
# where
# * $q$ is the uptake (mol·kg⁻¹),
# * $q_{\text{sat}}$ is the saturation capacity (mol·kg⁻¹),
# * $k(T)$ is the equilibrium constant (Pa⁻¹),
# * $P$ is the pressure (Pa).
#
# ---
#
# ### (a) High‑pressure limit $P \to \infty$ — uptake reaches plateau
#
# Divide numerator and denominator by $k(T)P$:
# $$
# q = \frac{q_{\text{sat}}}{\dfrac{1}{k(T)P} + 1}.
# $$
#
# As $P \to \infty$, the term $\dfrac{1}{k(T)P} \to 0$. Therefore
# $$
# \boxed{ q \xrightarrow[P\to\infty]{} q_{\text{sat}} }.
# $$
#
# **Interpretation:** at very large pressure all adsorption sites are occupied, so the uptake approaches the saturation loading $q_{\text{sat}}$.
#
# ---
#
# ### (b) Low‑pressure limit $P \to 0$ — linear dependence on $P$
#
# For small pressures $k(T)P \ll 1$.
# Approximate the denominator:
# $$
# q \approx \frac{q_{\text{sat}} k(T) P}{1} = q_{\text{sat}} k(T) P.
# $$
#
# Thus
# $$
# \boxed{ q \approx q_{\text{sat}} k(T) P \quad (P \to 0) }.
# $$
#
# This is linear in $P$ with slope $q_{\text{sat}} k(T)$.

# %% [markdown]
# ## 3) Temperature dependence of Henry's coefficient
#
# **Definition:**
# Henry's coefficient $K_H(T)$ is the initial slope of the isotherm at $P \to 0$:
# $$
# K_H(T) \equiv \left. \frac{\partial q}{\partial P} \right|_{P \to 0} = q_{\text{sat}}\,k(T).
# $$
#
# **Van't Hoff form for $k(T)$:**
# $$
# k(T) = k_0 \exp\!\left(-\frac{\Delta H}{R T}\right),
# $$
# so
# $$
# K_H(T) = q_{\text{sat}}\,k_0 \exp\!\left(-\frac{\Delta H}{R T}\right).
# $$
#
# **Interpretation:**
# $K_H$ follows an Arrhenius-like (exponential) dependence on $1/T$.
# If $\Delta H < 0$ (exothermic adsorption), $K_H$ decreases as temperature $T$ increases.

# %% [markdown]
# ## 4) How to obtain $q_{sat}$, $k_{0}$, and $\Delta H$ from isotherms
#
# We proceed in two mathematical steps, each with a corresponding plot.
#
# ---
#
# #### Step 1: Fit the isotherms at each temperature to the Langmuir model
#
# Given measured isotherms
# $$
# \bigl\{ \bigl(P_i^{(T)},\; q_i^{(T)} \bigr) \bigr\}
# $$
# at three temperatures $T = 263,\; 303,\; 343\;\mathrm{K}$.
#
# **Langmuir model**
# $$
# q\!\left(P;\; q_{sat}, k\right)
# = \frac{ q_{sat}\, k \, P }{ 1 + k \, P } .
# $$
#
# **Linearized form**
# $$
# \frac{P}{q} = \frac{1}{q_{sat} k(T)} + \frac{P}{q_{sat}} .
# $$
#
# **Procedure**
#
# * Fit each isotherm by plotting $\tfrac{P}{q}$ vs $P$:
#   - The **slope** is $1/q_{sat}$, which yields the saturation loading.
#   - The **intercept** is $1/[q_{sat}\,k(T)]$, from which $k(T)$ can be calculated.
#
# * Since $q_{sat}$ is independent of $T$, determine it once (e.g., at 263 K), and then use this value to extract $k(T)$ for 303 K and 343 K.
#
# **Graph 1:**
# Plot $P/q$ vs $P$ for each temperature, fit straight lines, and report the corresponding $q_{sat}$ and $k(T)$ values.
#
# ---
#
# #### Step 2: Van’t Hoff analysis to obtain $\Delta H$ and $k_{0}$
#
# With fitted $k(T)$ values from Step 1, use the Van’t Hoff relation:
#
# $$
# k(T) = k_{0}\,\exp\!\left(-\frac{\Delta H}{R\,T}\right)
# $$
#
# Linearized form:
# $$
# \ln k(T) = \ln k_{0} - \frac{\Delta H}{R}\,\frac{1}{T}.
# $$
#
# **Procedure**
#
# 1. Compute
#    $$
#    x_T = \frac{1}{T}, \qquad
#    y_T = \ln k(T).
#    $$
# 2. Fit the linear model
#    $$
#    y = a + b\,x ,
#    $$
#    where $a = \ln k_{0}$ and $b = -\dfrac{\Delta H}{R}$.
# 3. Extract parameters
#    $$
#    \Delta H = -b\,R, \qquad
#    k_{0} = e^{a}.
#    $$
#
# Use
# $$
# R = 8.314\;\mathrm{J\,mol^{-1}\,K^{-1}}
#    = 0.008314\;\mathrm{kJ\,mol^{-1}\,K^{-1}} .
# $$
#
# **Graph 2:**
# Plot $\ln k$ (y-axis) versus $1/T$ (x-axis), overlay the linear fit, and annotate slope and intercept to show $\Delta H$ and $k_{0}$.
#
# ---

# %% [markdown]
# ## 5) Langmuir Parameters and Henry Coefficients ##
#
#     qsat = 4.72 mmol/g
#     k(263) = 6.75e-06 1/Pa
#     k(303) = 1.48e-06 1/Pa
#     k(343) = 5.16e-07 1/Pa
#
# The function calculate_langmuir_parameters() gives back the answer for part A, and calculate_henry_coefficient() the answer for part B.

# %%
# PART A

import numpy as np
import matplotlib.pyplot as plt

def calculate_langmuir_parameters(temperatures, k_values):
    """
    Calculates k0 and delta H from temperature-dependent k values
    using the linearized Van't Hoff equation.

    The Van't Hoff equation is:
    ln(k) = ln(k0) - (delta H / R) * (1/T)

    This is in the form of a linear equation y = mx + c, where:
    y = ln(k)
    x = 1/T
    m = -delta H / R (the slope)
    c = ln(k0) (the y-intercept)

    Args:
        temperatures (list or np.array): A list of temperatures in Kelvin (K).
        k_values (list or np.array): A list of equilibrium constants (k) at
                                     each corresponding temperature.

    Returns:
        tuple: A tuple containing the calculated k0 and delta H values.
    """
    # Ideal gas constant R in kJ/(mol·K)
    # The assignment uses kJ/mol for delta H, so we use this value for R.
    R = 0.008314  # kJ/(mol·K)

    # Convert temperatures and k values for the linear plot
    inv_T = 1 / np.array(temperatures)
    ln_k = np.log(np.array(k_values))

    # The result is [slope, intercept]
    slope, intercept = np.polyfit(inv_T, ln_k, 1)

    # delta H from the slope
    delta_H = -slope * R

    # k0 from the y-intercept
    k0 = np.exp(intercept)

    # The results
    print("--- Van't Hoff Analysis ---")
    print(f"Slope (m) = {slope:.4f}")
    print(f"Y-intercept (c) = {intercept:.4f}")
    print("\nCalculated Parameters:")
    print(f"k0: {k0:.4e} 1/Pa")
    print(f"Delta H: {delta_H:.4f} kJ/mol")

    plt.figure(figsize=(8, 6))
    plt.plot(inv_T, ln_k, 'o', label='Experimental Data Points')
    plt.plot(inv_T, slope * inv_T + intercept, '-', label='Linear Fit')
    plt.xlabel('1/T (K⁻¹)')
    plt.ylabel('ln(k)')
    plt.title('Van\'t Hoff Plot')
    plt.legend()
    plt.grid(True)
    plt.show()

    return k0, delta_H

temperatures_data = [263, 303, 343]  # in K
k_values_data = [6.75e-06, 1.48e-06, 5.16e-07]  # in 1/Pa

k0_result, delta_H_result = calculate_langmuir_parameters(temperatures_data, k_values_data)

# PART B


def calculate_henry_coefficient(q_sat, temperatures, k_values):
    """
    Calculates the Henry's coefficient for each temperature and plots it.
    
    Args:
        q_sat (float): The saturation loading in mmol/g.
        temperatures (list or np.array): A list of temperatures in Kelvin (K).
        k_values (list or np.array): A list of equilibrium constants (k) at
                                     each corresponding temperature.
    
    Returns:
        list: A list of Henry's coefficients for each temperature.
    """
    print("\n--- Henry's Coefficient Calculation ---")
    henry_coefficients = []
    for T, k in zip(temperatures, k_values):
        kh = q_sat * k
        henry_coefficients.append(kh)
        print(f"Henry's Coefficient at {T} K: {kh:.4e} mmol/(g·Pa)")
    
    plt.figure(figsize=(8, 6))
    plt.plot(temperatures, henry_coefficients, 'bo-', linewidth=2, markersize=8, label='Henry\'s Coefficients')
    plt.xlabel('Temperature (K)')
    plt.ylabel('Henry\'s Coefficient (mmol/(g·Pa))')
    plt.title('Henry\'s Coefficient vs Temperature')
    plt.grid(True, alpha=0.7)
    plt.legend()
    
    
    for T, kh in zip(temperatures, henry_coefficients):
        plt.annotate(f'{kh:.2e}', (T, kh), textcoords="offset points", 
                    xytext=(0,10), ha='center', fontsize=9)
    
    plt.tight_layout()
    plt.show()
    
    return henry_coefficients

q_sat_data = 4.72  # mmol/g

henry_coeffs = calculate_henry_coefficient(q_sat_data, temperatures_data, k_values_data)
# Out:
# --- Van't Hoff Analysis ---
# Slope (m) = 2905.4431
# Y-intercept (c) = -22.9712
#
# Calculated Parameters:
# k0: 1.0562e-10 1/Pa
# Delta H: -24.1559 kJ/mol
# --- Henry's Coefficient Calculation ---
# Henry's Coefficient at 263 K: 3.1860e-05 mmol/(g·Pa)
# Henry's Coefficient at 303 K: 6.9856e-06 mmol/(g·Pa)
# Henry's Coefficient at 343 K: 2.4355e-06 mmol/(g·Pa)

# %% [markdown]
# ### Discussion of Henry's Coefficients Trend ###
#
# As the temperature increases, the Henry's coefficient decreases.
# This is expected because adsorption is an exothermic process,
# and a higher temperature reduces the affinity of the gas for the adsorbent,
# resulting in a lower uptake at low pressures.
# This is consistent with the principle of Le Châtelier.
#
# **Additional observations:**
# - The Henry's coefficient decreased from 3.19×10⁻⁵ mmol/(g·Pa) at 263 K to 2.44×10⁻⁶ mmol/(g·Pa) at 343 K, representing approximately a 13-fold decrease over an 80 K temperature range.
# - This temperature dependence follows an exponential relationship similar to the Langmuir constant k, since kH = qsat × k.
# - The steep decline indicates that this adsorbent material is significantly more effective at lower temperatures, which has important implications for process design and operating conditions.
# - This behavior is typical for physical adsorption processes, where van der Waals forces dominate the gas-solid interactions.
